# %%
import pandas as pd

# %%
ev= pd.read_csv('evaluation_trades.csv')

# %%
ev
# Out:
#              Entry Time            Exit Time   Type  Entry Price  Exit Price  \
# 0   2011-05-08 18:00:00  2011-05-09 16:00:00  Short      1.43527     1.43111
# 1   2011-05-09 18:00:00  2011-05-10 16:00:00  Short      1.43364     1.43539
# 2   2011-05-10 18:00:00  2011-05-11 16:00:00  Short      1.43942     1.42188
# 3   2011-05-11 18:00:00  2011-05-12 16:00:00  Short      1.41937     1.42319
# 4   2011-05-12 18:00:00  2011-05-13 16:00:00  Short      1.42278     1.41037
# ..                  ...                  ...    ...          ...         ...
# 78  2011-07-12 18:00:00  2011-07-12 19:00:00  Short      1.40270     1.39714
# 79  2011-07-12 19:00:00  2011-07-12 22:00:00   Long      1.39714     1.39697
# 80  2011-07-12 22:00:00  2011-07-13 08:00:00  Short      1.39697     1.40634
# 81  2011-07-13 08:00:00  2011-07-13 13:00:00   Long      1.40634     1.40460
# 82  2011-07-13 18:00:00  2011-07-13 21:00:00  Short      1.41442     1.42370
#
#          PnL    Return  Duration
# ...

# %%
com=pd.read_csv('final_combined_dataset.csv')
com
# Out:
#                      Time  Ren_Value  Blue  Red  dir  Yellow  Blue/Yellow  \
# 0     2010-07-15 01:00:00    1.27091     0    1    1       0            0
# 1     2010-07-15 02:00:00    1.27091     0    1    1       0            0
# 2     2010-07-15 03:00:00    1.27091     0    1    1       0            0
# 3     2010-07-15 04:00:00    1.27091     0    1    1       0            0
# 4     2010-07-15 05:00:00    1.27091     0    1    1       0            0
# ...                   ...        ...   ...  ...  ...     ...          ...
# 6977  2011-07-13 19:00:00    1.41714     1    0    0       0            0
# 6978  2011-07-13 20:00:00    1.41714     1    0    0       0            0
# 6979  2011-07-13 21:00:00    1.42370     1    0    0       0            0
# 6980  2011-07-13 22:00:00    1.42370     1    0    0       0            0
# 6981  2011-07-13 23:00:00    1.42370     1    0    0       0            0
#
#       Red/Yellow  Frac_Value  Flag  ...  enriched_91  enriched_92  \
# ...

# %%
.\env\python.exe run_pipeline.py --mode aggregate --use-ib --instrument EURUSD --granularity H1 --ib-port 7497
# Out:
#   Cell In[11], line 1
#     .\env\python.exe run_pipeline.py --mode aggregate --use-ib --instrument EURUSD --granularity H1 --ib-port 7497
#     ^
# SyntaxError: invalid syntax
